# %% [markdown]
# # Exploratory Data Analysis of Fireball dataset

# %%
import json
import os
from pathlib import Path

# %% [markdown]
# First we focus on the examples that are located in the official GiHub repository of [Fireball](https://github.com/zhudotexe/FIREBALL)

# %% [markdown]
# ## Filtered_triples

# %%
filtered_data_path = Path("filtered_triples.jsonl")

# %%
data = filtered_data_path.read_text().splitlines()

# %%
json.loads(data[11])
# Out:
# {'speaker_id': '15964394832197433734',
#  'before_utterances': ['*Then swipping with his whip towards the hags face.*'],
#  'combat_state_before': [{'name': 'Verity Silverdust',
#    'hp': '<18/18 HP; Healthy>',
#    'class': 'Rogue 3',
#    'race': 'Lightfoot Halfling',
#    'attacks': 'Dagger, Rapier, Shortbow, Unarmed Strike',
#    'spells': 'Sleep, Disguise Self, Message, Mage Armor, Prestidigitation, Mage Hand',
#    'actions': 'Steady Aim, Sneak Attack, Cunning Action',
#    'effects': 'Mage Armor',
#    'description': 'Halfling, Female, ?? years\nHeight: 3\'1"\nWeight: 42lbs\nHair: Blonde\nEyes: Blue\nSkin: Fair\n\n*too lazy to fill out the rest of the desc, remind me to do it later*',
#    'controller_id': '13086297142809228709'},
#   {'name': 'Nitar',
#    'hp': '<31/35 HP; Injured>',
#    'class': 'Barbarian 3',
#    'race': 'Shifter',
#    'attacks': 'Crystal Spike (Greataxe), Handaxe, Javelin, Unarmed Strike',
#    'spells': '',
# ...

# %% [markdown]
# ## Raw

# %%
path = Path("raw.jsonl")
data = iter(path.read_text().splitlines())

# %%
json.loads(next(data))
# Out:
# {'combat_id': '1669412158-d5e74f94-147e-4735-849b-7174b8aa8be0',
#  'event_type': 'command',
#  'timestamp': 1669412169.7837117,
#  'message_id': 1045815174952648734,
#  'author_id': '15964394832197433734',
#  'author_name': 'Player 2',
#  'author_bot': False,
#  'created_at': 1669412168.015,
#  'content': '!i join',
#  'embeds': [],
#  'components': [],
#  'referenced_message_id': None,
#  'prefix': '!',
#  'command_name': 'init join',
#  'called_by_alias': False,
#  'caster': {'name': 'Keya',
#   'stats': {'prof_bonus': 2,
#    'strength': 8,
#    'dexterity': 13,
#    'constitution': 13,
#    'intelligence': 14,
#    'wisdom': 9,
#    'charisma': 18},
#   'levels': {'total_level': 3, 'classes': {'Fighter': 2, 'Warlock': 1}},
#   'attacks': [{'name': 'Crossbow, light',
#     'automation': [{'type': 'target',
#       'target': 'each',
#       'effects': [{'type': 'attack',
#         'hit': [{'type': 'damage',
#           'damage': '1d8+1 [piercing]',
# ...
